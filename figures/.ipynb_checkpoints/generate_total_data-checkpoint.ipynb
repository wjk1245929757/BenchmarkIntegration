# %%
import pandas as pd
import numpy as np
input_dir = 'G:/dataset/result_index/'

# %%
experiment = 'MOSTA'
##### verticle slice
# df1 = pd.read_csv(input_dir + 'DLPFC_donor1_embedding_index.csv')
# df2 = pd.read_csv(input_dir + 'DLPFC_donor2_embedding_index.csv')
# df3 = pd.read_csv(input_dir + 'DLPFC_donor3_embedding_index.csv')

# df1 = pd.read_csv(input_dir + 'MouseAtlas_embryo1_embedding_index.csv')
# df2 = pd.read_csv(input_dir + 'MouseAtlas_embryo2_embedding_index.csv')
# df3 = pd.read_csv(input_dir + 'MouseAtlas_embryo3_embedding_index.csv')
# df_num = 3

##### horizon slice
# df1 = pd.read_csv(input_dir + 'Saggital_sample1_embedding_index.csv')
# df2 = pd.read_csv(input_dir + 'Saggital_sample2_embedding_index.csv')

# df1 = pd.read_csv(input_dir + 'LICA_embedding_index_k3.csv')
# df2 = pd.read_csv(input_dir + 'LICA_embedding_index_k4.csv')
# df_num = 2

##### sample
# df1 = pd.read_csv(input_dir + 'BRCA_index_embedding.csv')

# df1 = pd.read_csv(input_dir + 'PDAC_index_embedding.csv')

# df1 = pd.read_csv(input_dir + 'Coronal_index_embedding.csv')

# df1 = pd.read_csv(input_dir + 'mPFC_index_embedding.csv')

# df1 = pd.read_csv(input_dir + 'MOp_embedding_index.csv')

# df1 = pd.read_csv(input_dir + 'mouseOB35_index_embedding.csv')

df1 = pd.read_csv(input_dir + 'MOSTA_index_embedding.csv')
df_num = 1

# %%
df1
# Out:
#     Unnamed: 0   Sample      method cluster_method  spatial_coherence_score  \
# 0            0  embryo1      seurat   ground.truth              -804.980322
# 1            1  embryo1      seurat         leiden             -1097.960197
# 2            2  embryo1      seurat        louvain              -979.602598
# 3            3  embryo1      seurat         mclust             -1297.894810
# 4            0  embryo1     harmony   ground.truth              -881.130260
# 5            1  embryo1     harmony         leiden             -1107.062983
# 6            2  embryo1     harmony        louvain             -1140.006766
# 7            3  embryo1     harmony         mclust             -1220.451484
# 8            0  embryo1       liger   ground.truth              -770.597749
# 9            1  embryo1       liger         leiden              -906.361555
# 10           2  embryo1       liger        louvain              -948.499770
# 11           3  embryo1       liger         mclust             -1069.426622
# 12           0  embryo1     PRECAST   ground.truth              -827.939813
# 13           1  embryo1     PRECAST         leiden             -1093.562231
# 14           2  embryo1     PRECAST        louvain             -1019.839695
# 15           3  embryo1     PRECAST         mclust             -1009.709307
# 16           0  embryo1     STAGATE   ground.truth              -786.646021
# 17           1  embryo1     STAGATE         leiden             -1342.206191
# 18           2  embryo1     STAGATE        louvain             -1360.812464
# 19           3  embryo1     STAGATE         mclust             -1411.394441
# 20           0  embryo1   STAligner   ground.truth              -920.060812
# 21           1  embryo1   STAligner         leiden             -1360.454530
# 22           2  embryo1   STAligner        louvain             -1314.673807
# 23           3  embryo1   STAligner         mclust             -1511.581912
# 24           0  embryo1      DeepST   ground.truth              -866.713137
# 25           1  embryo1      DeepST         leiden              -745.941461
# 26           2  embryo1      DeepST        louvain              -701.085805
# 27           3  embryo1      DeepST         mclust              -813.260044
# 7                NaN  0.949359       NaN            0.973424  0.351839
# 8           0.288773  0.836188  0.386540            0.814341  0.325908
# 9                NaN  0.953721       NaN            1.000000  0.701711
# 10               NaN  0.958218       NaN            1.000000  0.675651
# 11               NaN  0.950562       NaN            0.976305  0.628010
# 12          0.294333  0.732012  0.339383            0.626895  0.373428
# 13               NaN  0.875173       NaN            1.000000  0.662681
# 14               NaN  0.875606       NaN            1.000000  0.677876
# 15               NaN  0.878321       NaN            0.997420  0.655422
# 16          0.394542  0.832256  0.269768            0.961053  0.120322
# 17               NaN  0.892566       NaN            1.000000  0.280458
# 18               NaN  0.882228       NaN            1.000000  0.252945
# 19               NaN  0.892638       NaN            0.994621  0.191556
# 20          0.381910  0.836291  0.278120            0.961626  0.115495
# 21               NaN  0.894223       NaN            1.000000  0.261785
# 22               NaN  0.895129       NaN            1.000000  0.190273
# 23               NaN  0.892011       NaN            0.994826  0.197558
# 24          0.493808  0.430909  0.000000            0.822369  0.034487
# 25               NaN  0.205321       NaN            1.000000  0.977823
# 26               NaN  0.217419       NaN            1.000000  0.978698
# 27               NaN  0.843459       NaN            0.996027  0.005654
# 28          0.584088  0.524431  0.000000            0.832776  0.025667
# 29               NaN  0.866108       NaN            1.000000  0.952358
# 30               NaN  0.702442       NaN            1.000000  0.971437
# 31               NaN  0.568737       NaN            0.931319  0.207488
# 32          0.341235  0.883402  0.296289            0.940191  0.140752
# 33               NaN  0.919226       NaN            1.000000  0.341457
# 34               NaN  0.912437       NaN            1.000000  0.292848
# 35               NaN  0.929467       NaN            0.985770  0.262748
#
#          PCR  Moran's I  Geary's C
# 0   0.993239   0.692488   0.242230
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4   0.997223   0.672028   0.247409
# 5        NaN        NaN        NaN
# 6        NaN        NaN        NaN
# 7        NaN        NaN        NaN
# 8   0.996681   0.930177   0.051439
# 9        NaN        NaN        NaN
# 10       NaN        NaN        NaN
# 11       NaN        NaN        NaN
# 12  0.985478   0.968079   0.007289
# 13       NaN        NaN        NaN
# 14       NaN        NaN        NaN
# 15       NaN        NaN        NaN
# 16  0.980955   0.951030   0.043461
# 17       NaN        NaN        NaN
# 18       NaN        NaN        NaN
# 19       NaN        NaN        NaN
# 20  0.982223   0.949548   0.044170
# 21       NaN        NaN        NaN
# 22       NaN        NaN        NaN
# 23       NaN        NaN        NaN
# 24  0.864408   0.973294   0.015210
# 25       NaN        NaN        NaN
# 26       NaN        NaN        NaN
# 27       NaN        NaN        NaN
# 28  0.448152   0.859624   0.120476
# 29       NaN        NaN        NaN
# 30       NaN        NaN        NaN
# 31       NaN        NaN        NaN
# 32  0.991405   0.828038   0.129816
# 33       NaN        NaN        NaN
# 34       NaN        NaN        NaN
# 35       NaN        NaN        NaN

# %% [markdown]
# # remove batch index

# %%
batch_columns = ['PCR', 'iASW', 'iLISI', 'kBET', 'graph_connectivity']

batch_df = pd.DataFrame()
batch_df['method'] = df1['method']
batch_df['cluster_method'] = df1['cluster_method']
for column in batch_columns:
    if df_num == 1:
        batch_df[column] = df1[column]
    elif df_num == 2:
        batch_df[column] = (df1[column] + df2[column]) / 2
    elif df_num == 3:
        batch_df[column] = (df1[column] + df2[column] + df3[column]) / 3

batch_df = batch_df[batch_df['cluster_method'] == 'ground.truth' ]
batch_df['batch_mean'] = batch_df[batch_columns].mean(axis=1, numeric_only=True)
batch_df['batch_median'] = batch_df[batch_columns].median(axis=1, numeric_only=True)
batch_df = batch_df.sort_values(by='batch_mean',ascending=False)
batch_df
# Out:
#         method cluster_method       PCR      iASW     iLISI      kBET  \
# 4      harmony   ground.truth  0.997223  0.891272  0.349823  0.199392
# 8        liger   ground.truth  0.996681  0.836188  0.386540  0.325908
# 0       seurat   ground.truth  0.993239  0.870109  0.324367  0.147769
# 32  SPIRAL_pyg   ground.truth  0.991405  0.883402  0.296289  0.140752
# 20   STAligner   ground.truth  0.982223  0.836291  0.278120  0.115495
# 16     STAGATE   ground.truth  0.980955  0.832256  0.269768  0.120322
# 12     PRECAST   ground.truth  0.985478  0.732012  0.339383  0.373428
# 24      DeepST   ground.truth  0.864408  0.430909  0.000000  0.034487
# 28     GraphST   ground.truth  0.448152  0.524431  0.000000  0.025667
#
#     graph_connectivity  batch_mean  batch_median
# 4             0.944855    0.676513      0.891272
# 8             0.814341    0.671931      0.814341
# 0             0.958874    0.658871      0.870109
# 32            0.940191    0.650408      0.883402
# 20            0.961626    0.634751      0.836291
# 16            0.961053    0.632871      0.832256
# 12            0.626895    0.611439      0.626895
# 24            0.822369    0.430435      0.430909
# 28            0.832776    0.366205      0.448152

# %% [markdown]
# # save info

# %%
info_columns = ['cASW', 'IsolatedLabelsAsw', 'cLISI', 'IsolatedLabelsF1', 'ARI', 'NMI']
info_df = pd.DataFrame()
info_df['method'] = df1['method']
info_df['cluster_method'] = df1['cluster_method']
for column in info_columns:
    if df_num == 1:
        info_df[column] = df1[column]
    elif df_num == 2:
        info_df[column] = (df1[column] + df2[column]) / 2
    elif df_num == 3:
        info_df[column] = (df1[column] + df2[column] + df3[column]) / 3

info_df
# Out:
#         method cluster_method      cASW  IsolatedLabelsAsw     cLISI  \
# 0       seurat   ground.truth  0.500644           0.505436  0.977580
# 1       seurat         leiden  0.560077           0.662845  0.996679
# 2       seurat        louvain  0.561044           0.736415  0.996962
# 3       seurat         mclust  0.531010           0.804685  0.985241
# 4      harmony   ground.truth  0.504168           0.493900  0.969209
# 5      harmony         leiden  0.546876           0.557866  0.992669
# 6      harmony        louvain  0.545271           0.557986  0.993166
# 7      harmony         mclust  0.515135           0.519233  0.968394
# 8        liger   ground.truth  0.496660           0.464194  0.953464
# 9        liger         leiden  0.597581           0.742990  0.996527
# 10       liger        louvain  0.589585           0.622307  0.995904
# 11       liger         mclust  0.484593           0.485923  0.945033
# 12     PRECAST   ground.truth  0.466250           0.412131  0.964579
# 13     PRECAST         leiden  0.844660           0.975051  1.000000
# 14     PRECAST        louvain  0.844593           0.975052  1.000000
# 15     PRECAST         mclust  0.827901           0.978194  1.000000
# 16     STAGATE   ground.truth  0.482072           0.494535  0.975966
# 17     STAGATE         leiden  0.521706           0.751779  0.994859
# 18     STAGATE        louvain  0.538902           0.548230  0.993335
# 19     STAGATE         mclust  0.540861           0.553117  0.984996
# 20   STAligner   ground.truth  0.479721           0.491454  0.973538
# 21   STAligner         leiden  0.546811           0.529534  0.993999
# 22   STAligner        louvain  0.545329           0.558071  0.992863
# 23   STAligner         mclust  0.537195           0.544606  0.982468
# 24      DeepST   ground.truth  0.399130           0.531418  0.986656
# 25      DeepST         leiden  0.630281           0.626039  0.999899
# 26      DeepST        louvain  0.621622           0.627853  0.999885
# 27      DeepST         mclust  0.551847           0.589030  0.997303
# 28     GraphST   ground.truth  0.455585           0.573576  0.989656
# 29     GraphST         leiden  0.563878           0.580363  0.998535
# 30     GraphST        louvain  0.574463           0.601228  0.998703
# 31     GraphST         mclust  0.540055           0.554815  0.993639
# 32  SPIRAL_pyg   ground.truth  0.505142           0.518820  0.964179
# 33  SPIRAL_pyg         leiden  0.547846           0.631884  0.987670
# 34  SPIRAL_pyg        louvain  0.541882           0.642785  0.988344
# 35  SPIRAL_pyg         mclust  0.535836           0.539528  0.971517
#
#     IsolatedLabelsF1       ARI       NMI
# 0           0.398110  1.000000  1.000000
# 1                NaN  0.391199  0.590378
# 2                NaN  0.351758  0.573835
# 3                NaN  0.288009  0.530057
# 4           0.387468  1.000000  1.000000
# 5                NaN  0.351396  0.561785
# 6                NaN  0.337757  0.551176
# 7                NaN  0.248469  0.480488
# 8           0.288773  1.000000  1.000000
# 9                NaN  0.272974  0.484175
# 10               NaN  0.254971  0.481814
# 11               NaN  0.176053  0.380429
# 12          0.294333  1.000000  1.000000
# 13               NaN  0.286310  0.564424
# 14               NaN  0.286278  0.564206
# 15               NaN  0.281034  0.555250
# 16          0.394542  1.000000  1.000000
# 17               NaN  0.336456  0.543888
# 18               NaN  0.285384  0.515669
# 19               NaN  0.301700  0.534991
# 20          0.381910  1.000000  1.000000
# 21               NaN  0.297168  0.523001
# 22               NaN  0.305830  0.517046
# 23               NaN  0.306265  0.540516
# 24          0.493808  1.000000  1.000000
# 25               NaN  0.294414  0.549797
# 26               NaN  0.293937  0.544668
# 27               NaN  0.225821  0.529490
# 28          0.584088  1.000000  1.000000
# 29               NaN  0.241477  0.536920
# 30               NaN  0.256400  0.543828
# 31               NaN  0.280161  0.570638
# 32          0.341235  1.000000  1.000000
# 33               NaN  0.305066  0.534818
# 34               NaN  0.304929  0.539910
# 35               NaN  0.281949  0.527169

# %%
info_df_ARI = info_df[['method', 'cluster_method', 'ARI']]
info_df_ARI = info_df_ARI[ info_df_ARI['cluster_method'] != 'ground.truth'  ]
info_df_ARI = info_df_ARI.sort_values(by='ARI',ascending=False)
print(info_df_ARI)

info_df_ARI = info_df_ARI.drop_duplicates(subset=['method'], keep='first')
print(info_df_ARI)
for index, row in info_df_ARI.iterrows():
    index_ = info_df.loc[ (info_df['cluster_method'] == 'ground.truth') & (info_df['method'] == row['method']) ].index.tolist()
    assert len(index_) == 1,'check shape'
    index_ = index_[0]
    info_df.loc[index_ , 'ARI'] = row['ARI']

info_df
# Out:
#         method cluster_method       ARI
# 1       seurat         leiden  0.391199
# 2       seurat        louvain  0.351758
# 5      harmony         leiden  0.351396
# 6      harmony        louvain  0.337757
# 17     STAGATE         leiden  0.336456
# 23   STAligner         mclust  0.306265
# 22   STAligner        louvain  0.305830
# 33  SPIRAL_pyg         leiden  0.305066
# 34  SPIRAL_pyg        louvain  0.304929
# 19     STAGATE         mclust  0.301700
# 21   STAligner         leiden  0.297168
# 25      DeepST         leiden  0.294414
# 26      DeepST        louvain  0.293937
# 3       seurat         mclust  0.288009
# 13     PRECAST         leiden  0.286310
# 14     PRECAST        louvain  0.286278
# 18     STAGATE        louvain  0.285384
# 35  SPIRAL_pyg         mclust  0.281949
# 15     PRECAST         mclust  0.281034
# 31     GraphST         mclust  0.280161
# 9        liger         leiden  0.272974
# 30     GraphST        louvain  0.256400
# 10       liger        louvain  0.254971
# 7      harmony         mclust  0.248469
# 29     GraphST         leiden  0.241477
# 27      DeepST         mclust  0.225821
# 11       liger         mclust  0.176053
#         method cluster_method       ARI
# 1       seurat         leiden  0.391199
# 5      harmony         leiden  0.351396
# 17     STAGATE         leiden  0.336456
# 23   STAligner         mclust  0.306265
# 33  SPIRAL_pyg         leiden  0.305066
# 25      DeepST         leiden  0.294414
# 13     PRECAST         leiden  0.286310
# 31     GraphST         mclust  0.280161
# 9        liger         leiden  0.272974
#         method cluster_method      cASW  IsolatedLabelsAsw     cLISI  \
# 0       seurat   ground.truth  0.500644           0.505436  0.977580
# 1       seurat         leiden  0.560077           0.662845  0.996679
# 2       seurat        louvain  0.561044           0.736415  0.996962
# 3       seurat         mclust  0.531010           0.804685  0.985241
# 4      harmony   ground.truth  0.504168           0.493900  0.969209
# 5      harmony         leiden  0.546876           0.557866  0.992669
# 6      harmony        louvain  0.545271           0.557986  0.993166
# 7      harmony         mclust  0.515135           0.519233  0.968394
# 8        liger   ground.truth  0.496660           0.464194  0.953464
# 9        liger         leiden  0.597581           0.742990  0.996527
# 10       liger        louvain  0.589585           0.622307  0.995904
# 11       liger         mclust  0.484593           0.485923  0.945033
# 12     PRECAST   ground.truth  0.466250           0.412131  0.964579
# 13     PRECAST         leiden  0.844660           0.975051  1.000000
# 14     PRECAST        louvain  0.844593           0.975052  1.000000
# 15     PRECAST         mclust  0.827901           0.978194  1.000000
# 16     STAGATE   ground.truth  0.482072           0.494535  0.975966
# 17     STAGATE         leiden  0.521706           0.751779  0.994859
# 18     STAGATE        louvain  0.538902           0.548230  0.993335
# 19     STAGATE         mclust  0.540861           0.553117  0.984996
# 20   STAligner   ground.truth  0.479721           0.491454  0.973538
# 21   STAligner         leiden  0.546811           0.529534  0.993999
# 22   STAligner        louvain  0.545329           0.558071  0.992863
# 23   STAligner         mclust  0.537195           0.544606  0.982468
# 24      DeepST   ground.truth  0.399130           0.531418  0.986656
# 25      DeepST         leiden  0.630281           0.626039  0.999899
# 26      DeepST        louvain  0.621622           0.627853  0.999885
# 27      DeepST         mclust  0.551847           0.589030  0.997303
# 28     GraphST   ground.truth  0.455585           0.573576  0.989656
# 29     GraphST         leiden  0.563878           0.580363  0.998535
# 30     GraphST        louvain  0.574463           0.601228  0.998703
# 31     GraphST         mclust  0.540055           0.554815  0.993639
# 32  SPIRAL_pyg   ground.truth  0.505142           0.518820  0.964179
# 33  SPIRAL_pyg         leiden  0.547846           0.631884  0.987670
# 34  SPIRAL_pyg        louvain  0.541882           0.642785  0.988344
# 35  SPIRAL_pyg         mclust  0.535836           0.539528  0.971517
#
#     IsolatedLabelsF1       ARI       NMI
# 0           0.398110  0.391199  1.000000
# 1                NaN  0.391199  0.590378
# 2                NaN  0.351758  0.573835
# 3                NaN  0.288009  0.530057
# 4           0.387468  0.351396  1.000000
# 5                NaN  0.351396  0.561785
# 6                NaN  0.337757  0.551176
# 7                NaN  0.248469  0.480488
# 8           0.288773  0.272974  1.000000
# 9                NaN  0.272974  0.484175
# 10               NaN  0.254971  0.481814
# 11               NaN  0.176053  0.380429
# 12          0.294333  0.286310  1.000000
# 13               NaN  0.286310  0.564424
# 14               NaN  0.286278  0.564206
# 15               NaN  0.281034  0.555250
# 16          0.394542  0.336456  1.000000
# 17               NaN  0.336456  0.543888
# 18               NaN  0.285384  0.515669
# 19               NaN  0.301700  0.534991
# 20          0.381910  0.306265  1.000000
# 21               NaN  0.297168  0.523001
# 22               NaN  0.305830  0.517046
# 23               NaN  0.306265  0.540516
# 24          0.493808  0.294414  1.000000
# 25               NaN  0.294414  0.549797
# 26               NaN  0.293937  0.544668
# 27               NaN  0.225821  0.529490
# 28          0.584088  0.280161  1.000000
# 29               NaN  0.241477  0.536920
# 30               NaN  0.256400  0.543828
# 31               NaN  0.280161  0.570638
# 32          0.341235  0.305066  1.000000
# 33               NaN  0.305066  0.534818
# 34               NaN  0.304929  0.539910
# 35               NaN  0.281949  0.527169

# %%
info_df_NMI = info_df[['method', 'cluster_method', 'NMI']]
info_df_NMI = info_df_NMI[ info_df_NMI['cluster_method'] != 'ground.truth'  ]
info_df_NMI = info_df_NMI.sort_values(by='NMI',ascending=False)

info_df_NMI = info_df_NMI.drop_duplicates(subset=['method'], keep='first')
info_df_NMI
for index, row in info_df_NMI.iterrows():
    index_ = info_df.loc[ (info_df['cluster_method'] == 'ground.truth') & (info_df['method'] == row['method']) ].index.tolist()
    assert len(index_) == 1,'check shape'
    index_ = index_[0]
    info_df.loc[index_ , 'NMI'] = row['NMI']

info_df
# Out:
#         method cluster_method      cASW  IsolatedLabelsAsw     cLISI  \
# 0       seurat   ground.truth  0.500644           0.505436  0.977580
# 1       seurat         leiden  0.560077           0.662845  0.996679
# 2       seurat        louvain  0.561044           0.736415  0.996962
# 3       seurat         mclust  0.531010           0.804685  0.985241
# 4      harmony   ground.truth  0.504168           0.493900  0.969209
# 5      harmony         leiden  0.546876           0.557866  0.992669
# 6      harmony        louvain  0.545271           0.557986  0.993166
# 7      harmony         mclust  0.515135           0.519233  0.968394
# 8        liger   ground.truth  0.496660           0.464194  0.953464
# 9        liger         leiden  0.597581           0.742990  0.996527
# 10       liger        louvain  0.589585           0.622307  0.995904
# 11       liger         mclust  0.484593           0.485923  0.945033
# 12     PRECAST   ground.truth  0.466250           0.412131  0.964579
# 13     PRECAST         leiden  0.844660           0.975051  1.000000
# 14     PRECAST        louvain  0.844593           0.975052  1.000000
# 15     PRECAST         mclust  0.827901           0.978194  1.000000
# 16     STAGATE   ground.truth  0.482072           0.494535  0.975966
# 17     STAGATE         leiden  0.521706           0.751779  0.994859
# 18     STAGATE        louvain  0.538902           0.548230  0.993335
# 19     STAGATE         mclust  0.540861           0.553117  0.984996
# 20   STAligner   ground.truth  0.479721           0.491454  0.973538
# 21   STAligner         leiden  0.546811           0.529534  0.993999
# 22   STAligner        louvain  0.545329           0.558071  0.992863
# 23   STAligner         mclust  0.537195           0.544606  0.982468
# 24      DeepST   ground.truth  0.399130           0.531418  0.986656
# 25      DeepST         leiden  0.630281           0.626039  0.999899
# 26      DeepST        louvain  0.621622           0.627853  0.999885
# 27      DeepST         mclust  0.551847           0.589030  0.997303
# 28     GraphST   ground.truth  0.455585           0.573576  0.989656
# 29     GraphST         leiden  0.563878           0.580363  0.998535
# 30     GraphST        louvain  0.574463           0.601228  0.998703
# 31     GraphST         mclust  0.540055           0.554815  0.993639
# 32  SPIRAL_pyg   ground.truth  0.505142           0.518820  0.964179
# 33  SPIRAL_pyg         leiden  0.547846           0.631884  0.987670
# 34  SPIRAL_pyg        louvain  0.541882           0.642785  0.988344
# 35  SPIRAL_pyg         mclust  0.535836           0.539528  0.971517
#
#     IsolatedLabelsF1       ARI       NMI
# 0           0.398110  0.391199  0.590378
# 1                NaN  0.391199  0.590378
# 2                NaN  0.351758  0.573835
# 3                NaN  0.288009  0.530057
# 4           0.387468  0.351396  0.561785
# 5                NaN  0.351396  0.561785
# 6                NaN  0.337757  0.551176
# 7                NaN  0.248469  0.480488
# 8           0.288773  0.272974  0.484175
# 9                NaN  0.272974  0.484175
# 10               NaN  0.254971  0.481814
# 11               NaN  0.176053  0.380429
# 12          0.294333  0.286310  0.564424
# 13               NaN  0.286310  0.564424
# 14               NaN  0.286278  0.564206
# 15               NaN  0.281034  0.555250
# 16          0.394542  0.336456  0.543888
# 17               NaN  0.336456  0.543888
# 18               NaN  0.285384  0.515669
# 19               NaN  0.301700  0.534991
# 20          0.381910  0.306265  0.540516
# 21               NaN  0.297168  0.523001
# 22               NaN  0.305830  0.517046
# 23               NaN  0.306265  0.540516
# 24          0.493808  0.294414  0.549797
# 25               NaN  0.294414  0.549797
# 26               NaN  0.293937  0.544668
# 27               NaN  0.225821  0.529490
# 28          0.584088  0.280161  0.570638
# 29               NaN  0.241477  0.536920
# 30               NaN  0.256400  0.543828
# 31               NaN  0.280161  0.570638
# 32          0.341235  0.305066  0.539910
# 33               NaN  0.305066  0.534818
# 34               NaN  0.304929  0.539910
# 35               NaN  0.281949  0.527169

# %%
info_df = info_df[info_df['cluster_method'] == 'ground.truth' ]
info_df['info_mean'] = info_df[info_columns].mean(axis=1, numeric_only=True)
info_df['info_median'] = info_df[info_columns].median(axis=1, numeric_only=True)
info_df = info_df.sort_values(by='info_mean',ascending=False)
info_df
# Out:
# C:\Users\23147\AppData\Local\Temp\ipykernel_12240\2912173736.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_df['info_mean'] = info_df[info_columns].mean(axis=1, numeric_only=True)
# C:\Users\23147\AppData\Local\Temp\ipykernel_12240\2912173736.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_df['info_median'] = info_df[info_columns].median(axis=1, numeric_only=True)
#         method cluster_method      cASW  IsolatedLabelsAsw     cLISI  \
# 28     GraphST   ground.truth  0.455585           0.573576  0.989656
# 0       seurat   ground.truth  0.500644           0.505436  0.977580
# 4      harmony   ground.truth  0.504168           0.493900  0.969209
# 24      DeepST   ground.truth  0.399130           0.531418  0.986656
# 16     STAGATE   ground.truth  0.482072           0.494535  0.975966
# 32  SPIRAL_pyg   ground.truth  0.505142           0.518820  0.964179
# 20   STAligner   ground.truth  0.479721           0.491454  0.973538
# 12     PRECAST   ground.truth  0.466250           0.412131  0.964579
# 8        liger   ground.truth  0.496660           0.464194  0.953464
#
#     IsolatedLabelsF1       ARI       NMI  info_mean  info_median
# 28          0.584088  0.280161  0.570638   0.575617     0.572107
# 0           0.398110  0.391199  0.590378   0.560558     0.503040
# 4           0.387468  0.351396  0.561785   0.544654     0.499034
# 24          0.493808  0.294414  0.549797   0.542537     0.512613
# 16          0.394542  0.336456  0.543888   0.537910     0.488304
# 32          0.341235  0.305066  0.539910   0.529059     0.511981
# 20          0.381910  0.306265  0.540516   0.528901     0.485587
# 12          0.294333  0.286310  0.564424   0.498004     0.439190
# 8           0.288773  0.272974  0.484175   0.493373     0.474184

# %% [markdown]
# # spatial index

# %%
spatial_columns = ['spatial_coherence_score', "Moran's I", "Geary's C"]
spatial_df = pd.DataFrame()
spatial_df['method'] = df1['method']
spatial_df['cluster_method'] = df1['cluster_method']
for column in spatial_columns:
    if df_num == 1:
        spatial_df[column] = df1[column]
    elif df_num == 2:
        spatial_df[column] = (df1[column] + df2[column]) / 2
    elif df_num == 3:
        spatial_df[column] = (df1[column] + df2[column] + df3[column]) / 3
    
spatial_df["Geary's C"] = 1 - spatial_df["Geary's C"]
    
spatial_df
# Out:
#         method cluster_method  spatial_coherence_score  Moran's I  Geary's C
# 0       seurat   ground.truth              -804.980322   0.692488   0.757770
# 1       seurat         leiden             -1097.960197        NaN        NaN
# 2       seurat        louvain              -979.602598        NaN        NaN
# 3       seurat         mclust             -1297.894810        NaN        NaN
# 4      harmony   ground.truth              -881.130260   0.672028   0.752591
# 5      harmony         leiden             -1107.062983        NaN        NaN
# 6      harmony        louvain             -1140.006766        NaN        NaN
# 7      harmony         mclust             -1220.451484        NaN        NaN
# 8        liger   ground.truth              -770.597749   0.930177   0.948561
# 9        liger         leiden              -906.361555        NaN        NaN
# 10       liger        louvain              -948.499770        NaN        NaN
# 11       liger         mclust             -1069.426622        NaN        NaN
# 12     PRECAST   ground.truth              -827.939813   0.968079   0.992711
# 13     PRECAST         leiden             -1093.562231        NaN        NaN
# 14     PRECAST        louvain             -1019.839695        NaN        NaN
# 15     PRECAST         mclust             -1009.709307        NaN        NaN
# 16     STAGATE   ground.truth              -786.646021   0.951030   0.956539
# 17     STAGATE         leiden             -1342.206191        NaN        NaN
# 18     STAGATE        louvain             -1360.812464        NaN        NaN
# 19     STAGATE         mclust             -1411.394441        NaN        NaN
# 20   STAligner   ground.truth              -920.060812   0.949548   0.955830
# 21   STAligner         leiden             -1360.454530        NaN        NaN
# 22   STAligner        louvain             -1314.673807        NaN        NaN
# 23   STAligner         mclust             -1511.581912        NaN        NaN
# 24      DeepST   ground.truth              -866.713137   0.973294   0.984790
# 25      DeepST         leiden              -745.941461        NaN        NaN
# 26      DeepST        louvain              -701.085805        NaN        NaN
# 27      DeepST         mclust              -813.260044        NaN        NaN
# 28     GraphST   ground.truth              -756.129000   0.859624   0.879524
# 29     GraphST         leiden              -616.155784        NaN        NaN
# 30     GraphST        louvain              -609.288460        NaN        NaN
# 31     GraphST         mclust              -981.939489        NaN        NaN
# 32  SPIRAL_pyg   ground.truth              -782.563248   0.828038   0.870184
# 33  SPIRAL_pyg         leiden             -1184.876470        NaN        NaN
# 34  SPIRAL_pyg        louvain              -874.660181        NaN        NaN
# 35  SPIRAL_pyg         mclust             -1228.226400        NaN        NaN

# %%
spatial_df_scs = spatial_df[['method', 'cluster_method', 'spatial_coherence_score']]
spatial_df_scs = spatial_df_scs[ spatial_df_scs['cluster_method'] != 'ground.truth'  ]

print(spatial_df_scs)

spatial_df_scs['spatial_coherence_score'] = spatial_df_scs['spatial_coherence_score'].abs()
spatial_df_scs = spatial_df_scs.sort_values(by='spatial_coherence_score',ascending=False)
spatial_df_scs = spatial_df_scs.drop_duplicates(subset=['method'], keep='first')

print(spatial_df_scs)

max_value = spatial_df_scs['spatial_coherence_score'].max()
spatial_df_scs['spatial_coherence_score'] = spatial_df_scs['spatial_coherence_score'] / max_value
spatial_df_scs
for index, row in spatial_df_scs.iterrows():
    index_ = spatial_df.loc[ (spatial_df['cluster_method'] == 'ground.truth') & (spatial_df['method'] == row['method']) ].index.tolist()
    print(index_)
    assert len(index_) == 1,'check shape'
    spatial_df.loc[index_ , 'spatial_coherence_score'] = row['spatial_coherence_score']
# Out:
#         method cluster_method  spatial_coherence_score
# 1       seurat         leiden             -1097.960197
# 2       seurat        louvain              -979.602598
# 3       seurat         mclust             -1297.894810
# 5      harmony         leiden             -1107.062983
# 6      harmony        louvain             -1140.006766
# 7      harmony         mclust             -1220.451484
# 9        liger         leiden              -906.361555
# 10       liger        louvain              -948.499770
# 11       liger         mclust             -1069.426622
# 13     PRECAST         leiden             -1093.562231
# 14     PRECAST        louvain             -1019.839695
# 15     PRECAST         mclust             -1009.709307
# 17     STAGATE         leiden             -1342.206191
# 18     STAGATE        louvain             -1360.812464
# 19     STAGATE         mclust             -1411.394441
# 21   STAligner         leiden             -1360.454530
# 22   STAligner        louvain             -1314.673807
# 23   STAligner         mclust             -1511.581912
# 25      DeepST         leiden              -745.941461
# 26      DeepST        louvain              -701.085805
# 27      DeepST         mclust              -813.260044
# 29     GraphST         leiden              -616.155784
# 30     GraphST        louvain              -609.288460
# 31     GraphST         mclust              -981.939489
# 33  SPIRAL_pyg         leiden             -1184.876470
# 34  SPIRAL_pyg        louvain              -874.660181
# 35  SPIRAL_pyg         mclust             -1228.226400
#         method cluster_method  spatial_coherence_score
# 23   STAligner         mclust              1511.581912
# 19     STAGATE         mclust              1411.394441
# 3       seurat         mclust              1297.894810
# 35  SPIRAL_pyg         mclust              1228.226400
# 7      harmony         mclust              1220.451484
# 13     PRECAST         leiden              1093.562231
# 11       liger         mclust              1069.426622
# 31     GraphST         mclust               981.939489
# 27      DeepST         mclust               813.260044
# [20]
# [16]
# [0]
# [32]
# [4]
# [12]
# [8]
# [28]
# [24]

# %%
spatial_df
# Out:
#         method cluster_method  spatial_coherence_score  Moran's I  Geary's C
# 0       seurat   ground.truth                 0.858633   0.692488   0.757770
# 1       seurat         leiden             -1097.960197        NaN        NaN
# 2       seurat        louvain              -979.602598        NaN        NaN
# 3       seurat         mclust             -1297.894810        NaN        NaN
# 4      harmony   ground.truth                 0.807400   0.672028   0.752591
# 5      harmony         leiden             -1107.062983        NaN        NaN
# 6      harmony        louvain             -1140.006766        NaN        NaN
# 7      harmony         mclust             -1220.451484        NaN        NaN
# 8        liger   ground.truth                 0.707488   0.930177   0.948561
# 9        liger         leiden              -906.361555        NaN        NaN
# 10       liger        louvain              -948.499770        NaN        NaN
# 11       liger         mclust             -1069.426622        NaN        NaN
# 12     PRECAST   ground.truth                 0.723455   0.968079   0.992711
# 13     PRECAST         leiden             -1093.562231        NaN        NaN
# 14     PRECAST        louvain             -1019.839695        NaN        NaN
# 15     PRECAST         mclust             -1009.709307        NaN        NaN
# 16     STAGATE   ground.truth                 0.933720   0.951030   0.956539
# 17     STAGATE         leiden             -1342.206191        NaN        NaN
# 18     STAGATE        louvain             -1360.812464        NaN        NaN
# 19     STAGATE         mclust             -1411.394441        NaN        NaN
# 20   STAligner   ground.truth                 1.000000   0.949548   0.955830
# 21   STAligner         leiden             -1360.454530        NaN        NaN
# 22   STAligner        louvain             -1314.673807        NaN        NaN
# 23   STAligner         mclust             -1511.581912        NaN        NaN
# 24      DeepST   ground.truth                 0.538019   0.973294   0.984790
# 25      DeepST         leiden              -745.941461        NaN        NaN
# 26      DeepST        louvain              -701.085805        NaN        NaN
# 27      DeepST         mclust              -813.260044        NaN        NaN
# 28     GraphST   ground.truth                 0.649611   0.859624   0.879524
# 29     GraphST         leiden              -616.155784        NaN        NaN
# 30     GraphST        louvain              -609.288460        NaN        NaN
# 31     GraphST         mclust              -981.939489        NaN        NaN
# 32  SPIRAL_pyg   ground.truth                 0.812544   0.828038   0.870184
# 33  SPIRAL_pyg         leiden             -1184.876470        NaN        NaN
# 34  SPIRAL_pyg        louvain              -874.660181        NaN        NaN
# 35  SPIRAL_pyg         mclust             -1228.226400        NaN        NaN

# %%
spatial_df = spatial_df[spatial_df['cluster_method'] == 'ground.truth' ]
spatial_df['spatial_mean'] = spatial_df[spatial_columns].mean(axis=1, numeric_only=True)
spatial_df['spatial_median'] = spatial_df[spatial_columns].median(axis=1, numeric_only=True)
spatial_df = spatial_df.sort_values(by='spatial_median',ascending=False)
spatial_df
# Out:
# C:\Users\23147\AppData\Local\Temp\ipykernel_12240\759273103.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spatial_df['spatial_mean'] = spatial_df[spatial_columns].mean(axis=1, numeric_only=True)
# C:\Users\23147\AppData\Local\Temp\ipykernel_12240\759273103.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spatial_df['spatial_median'] = spatial_df[spatial_columns].median(axis=1, numeric_only=True)
#         method cluster_method  spatial_coherence_score  Moran's I  Geary's C  \
# 24      DeepST   ground.truth                 0.538019   0.973294   0.984790
# 12     PRECAST   ground.truth                 0.723455   0.968079   0.992711
# 20   STAligner   ground.truth                 1.000000   0.949548   0.955830
# 16     STAGATE   ground.truth                 0.933720   0.951030   0.956539
# 8        liger   ground.truth                 0.707488   0.930177   0.948561
# 28     GraphST   ground.truth                 0.649611   0.859624   0.879524
# 32  SPIRAL_pyg   ground.truth                 0.812544   0.828038   0.870184
# 0       seurat   ground.truth                 0.858633   0.692488   0.757770
# 4      harmony   ground.truth                 0.807400   0.672028   0.752591
#
#     spatial_mean  spatial_median
# 24      0.832035        0.973294
# 12      0.894749        0.968079
# 20      0.968459        0.955830
# 16      0.947096        0.951030
# 8       0.862075        0.930177
# 28      0.796253        0.859624
# 32      0.836922        0.828038
# 0       0.769630        0.757770
# 4       0.744006        0.752591

# %%
spatial_df = spatial_df.sort_values(by='spatial_mean',ascending=False)
spatial_df
# Out:
#         method cluster_method  spatial_coherence_score  Moran's I  Geary's C  \
# 20   STAligner   ground.truth                 1.000000   0.949548   0.955830
# 16     STAGATE   ground.truth                 0.933720   0.951030   0.956539
# 12     PRECAST   ground.truth                 0.723455   0.968079   0.992711
# 8        liger   ground.truth                 0.707488   0.930177   0.948561
# 32  SPIRAL_pyg   ground.truth                 0.812544   0.828038   0.870184
# 24      DeepST   ground.truth                 0.538019   0.973294   0.984790
# 28     GraphST   ground.truth                 0.649611   0.859624   0.879524
# 0       seurat   ground.truth                 0.858633   0.692488   0.757770
# 4      harmony   ground.truth                 0.807400   0.672028   0.752591
#
#     spatial_mean  spatial_median
# 20      0.968459        0.955830
# 16      0.947096        0.951030
# 12      0.894749        0.968079
# 8       0.862075        0.930177
# 32      0.836922        0.828038
# 24      0.832035        0.973294
# 28      0.796253        0.859624
# 0       0.769630        0.757770
# 4       0.744006        0.752591

# %% [markdown]
# # merge dataframe

# %%
batch_df.index = batch_df['method']

info_df.index = info_df['method']

spatial_df.index = spatial_df['method']

index_all_df = pd.concat([batch_df, info_df, spatial_df],axis=1)

del index_all_df['method']
del index_all_df['cluster_method']


index_all_df['mean'] = index_all_df[['batch_mean', 'info_mean', 'spatial_mean']].mean(axis=1, numeric_only=True)
# index_all_df['mean'] = index_all_df[batch_columns+info_columns+spatial_columns].mean(axis=1, numeric_only=True)
index_all_df['median'] = index_all_df[['batch_median', 'info_median', 'spatial_median']].mean(axis=1, numeric_only=True)

index_all_df = index_all_df.sort_values(by='median',ascending=False)

index_all_df
# Out:
#                  PCR      iASW     iLISI      kBET  graph_connectivity  \
# method
# STAligner   0.982223  0.836291  0.278120  0.115495            0.961626
# STAGATE     0.980955  0.832256  0.269768  0.120322            0.961053
# SPIRAL_pyg  0.991405  0.883402  0.296289  0.140752            0.940191
# liger       0.996681  0.836188  0.386540  0.325908            0.814341
# harmony     0.997223  0.891272  0.349823  0.199392            0.944855
# seurat      0.993239  0.870109  0.324367  0.147769            0.958874
# PRECAST     0.985478  0.732012  0.339383  0.373428            0.626895
# DeepST      0.864408  0.430909  0.000000  0.034487            0.822369
# GraphST     0.448152  0.524431  0.000000  0.025667            0.832776
#
#             batch_mean  batch_median      cASW  IsolatedLabelsAsw     cLISI  \
# method
# STAligner     0.634751      0.836291  0.479721           0.491454  0.973538
# STAGATE       0.632871      0.832256  0.482072           0.494535  0.975966
# SPIRAL_pyg    0.650408      0.883402  0.505142           0.518820  0.964179
# liger         0.671931      0.814341  0.496660           0.464194  0.953464
# harmony       0.676513      0.891272  0.504168           0.493900  0.969209
# seurat        0.658871      0.870109  0.500644           0.505436  0.977580
# PRECAST       0.611439      0.626895  0.466250           0.412131  0.964579
# DeepST        0.430435      0.430909  0.399130           0.531418  0.986656
# GraphST       0.366205      0.448152  0.455585           0.573576  0.989656
#
#             ...       NMI  info_mean  info_median  spatial_coherence_score  \
# method      ...
# STAligner   ...  0.540516   0.528901     0.485587                 1.000000
# STAGATE     ...  0.543888   0.537910     0.488304                 0.933720
# SPIRAL_pyg  ...  0.539910   0.529059     0.511981                 0.812544
# liger       ...  0.484175   0.493373     0.474184                 0.707488
# harmony     ...  0.561785   0.544654     0.499034                 0.807400
# seurat      ...  0.590378   0.560558     0.503040                 0.858633
# PRECAST     ...  0.564424   0.498004     0.439190                 0.723455
# DeepST      ...  0.549797   0.542537     0.512613                 0.538019
# GraphST     ...  0.570638   0.575617     0.572107                 0.649611
#
#             Moran's I  Geary's C  spatial_mean  spatial_median      mean  \
# method
# STAligner    0.949548   0.955830      0.968459        0.955830  0.710704
# STAGATE      0.951030   0.956539      0.947096        0.951030  0.705959
# SPIRAL_pyg   0.828038   0.870184      0.836922        0.828038  0.672129
# liger        0.930177   0.948561      0.862075        0.930177  0.675793
# harmony      0.672028   0.752591      0.744006        0.752591  0.655058
# seurat       0.692488   0.757770      0.769630        0.757770  0.663020
# PRECAST      0.968079   0.992711      0.894749        0.968079  0.668064
# DeepST       0.973294   0.984790      0.832035        0.973294  0.601669
# GraphST      0.859624   0.879524      0.796253        0.859624  0.579358
#
#               median
# method
# STAligner   0.759236
# STAGATE     0.757197
# SPIRAL_pyg  0.741141
# liger       0.739568
# harmony     0.714299
# seurat      0.710306
# PRECAST     0.678055
# DeepST      0.638939
# GraphST     0.626627
#
# [9 rows x 22 columns]

# %%
# index_all_df = index_all_df[index_all_df.index!='GraphST3000']
# index_all_df
index_all_df = index_all_df.sort_values(by='mean',ascending=False)
index_all_df
# Out:
#                  PCR      iASW     iLISI      kBET  graph_connectivity  \
# method
# STAligner   0.982223  0.836291  0.278120  0.115495            0.961626
# STAGATE     0.980955  0.832256  0.269768  0.120322            0.961053
# liger       0.996681  0.836188  0.386540  0.325908            0.814341
# SPIRAL_pyg  0.991405  0.883402  0.296289  0.140752            0.940191
# PRECAST     0.985478  0.732012  0.339383  0.373428            0.626895
# seurat      0.993239  0.870109  0.324367  0.147769            0.958874
# harmony     0.997223  0.891272  0.349823  0.199392            0.944855
# DeepST      0.864408  0.430909  0.000000  0.034487            0.822369
# GraphST     0.448152  0.524431  0.000000  0.025667            0.832776
#
#             batch_mean  batch_median      cASW  IsolatedLabelsAsw     cLISI  \
# method
# STAligner     0.634751      0.836291  0.479721           0.491454  0.973538
# STAGATE       0.632871      0.832256  0.482072           0.494535  0.975966
# liger         0.671931      0.814341  0.496660           0.464194  0.953464
# SPIRAL_pyg    0.650408      0.883402  0.505142           0.518820  0.964179
# PRECAST       0.611439      0.626895  0.466250           0.412131  0.964579
# seurat        0.658871      0.870109  0.500644           0.505436  0.977580
# harmony       0.676513      0.891272  0.504168           0.493900  0.969209
# DeepST        0.430435      0.430909  0.399130           0.531418  0.986656
# GraphST       0.366205      0.448152  0.455585           0.573576  0.989656
#
#             ...       NMI  info_mean  info_median  spatial_coherence_score  \
# method      ...
# STAligner   ...  0.540516   0.528901     0.485587                 1.000000
# STAGATE     ...  0.543888   0.537910     0.488304                 0.933720
# liger       ...  0.484175   0.493373     0.474184                 0.707488
# SPIRAL_pyg  ...  0.539910   0.529059     0.511981                 0.812544
# PRECAST     ...  0.564424   0.498004     0.439190                 0.723455
# seurat      ...  0.590378   0.560558     0.503040                 0.858633
# harmony     ...  0.561785   0.544654     0.499034                 0.807400
# DeepST      ...  0.549797   0.542537     0.512613                 0.538019
# GraphST     ...  0.570638   0.575617     0.572107                 0.649611
#
#             Moran's I  Geary's C  spatial_mean  spatial_median      mean  \
# method
# STAligner    0.949548   0.955830      0.968459        0.955830  0.710704
# STAGATE      0.951030   0.956539      0.947096        0.951030  0.705959
# liger        0.930177   0.948561      0.862075        0.930177  0.675793
# SPIRAL_pyg   0.828038   0.870184      0.836922        0.828038  0.672129
# PRECAST      0.968079   0.992711      0.894749        0.968079  0.668064
# seurat       0.692488   0.757770      0.769630        0.757770  0.663020
# harmony      0.672028   0.752591      0.744006        0.752591  0.655058
# DeepST       0.973294   0.984790      0.832035        0.973294  0.601669
# GraphST      0.859624   0.879524      0.796253        0.859624  0.579358
#
#               median
# method
# STAligner   0.759236
# STAGATE     0.757197
# liger       0.739568
# SPIRAL_pyg  0.741141
# PRECAST     0.678055
# seurat      0.710306
# harmony     0.714299
# DeepST      0.638939
# GraphST     0.626627
#
# [9 rows x 22 columns]

# %%
index_all_df = index_all_df.sort_values(by='mean',ascending=True)   ##  R plot need reverse
index_all_df.to_csv('G:/dataset/result_pic/index_res/'+experiment+'.csv')

# %% [markdown]
# # merge dataframe

# %%
import pandas as pd
import numpy as np
input_dir = 'G:/dataset/result_pic/index_res/total_plot/'
df1 = pd.read_csv(input_dir + 'DLPFC_slice.csv', index_col=0)
df2 = pd.read_csv(input_dir + 'MouseAtlas_slice.csv', index_col=0)
df3 = pd.read_csv(input_dir + 'Saggital_horizon.csv', index_col=0)
df4 = pd.read_csv(input_dir + 'LICA_horizon.csv', index_col=0)
df4
# Out:
#                 PCR      iASW         iLISI      kBET  graph_connectivity  \
# method
# DeepST     0.752862  0.663634  0.032893  0.064096            0.966555
# PRECAST    0.132825  0.607518  0.346634  0.263279            0.810745
# liger      0.541001  0.717841  0.521744  0.271680            0.953423
# GraphST    0.900632  0.755228  0.902414  0.228824            0.975503
# SPIRAL     0.482332  0.757606  0.485104  0.398070            0.966584
#
#            batch_mean  batch_median      cASW  IsolatedLabelsAsw     cLISI  \
# method
# harmony      0.443529      0.278416  0.537224           0.645572  0.982281
# STAGATE      0.355377      0.160524  0.533538           0.655155  0.985226
# seurat       0.505701      0.352543  0.533396           0.629854  0.979993
# STAligner    0.393275      0.226751  0.531111           0.642926  0.976933
# DeepST       0.496008      0.663634  0.484700           0.632757  0.979246
# PRECAST      0.432200      0.346634  0.550398           0.629979  0.957865
# liger        0.601138      0.541001  0.528586           0.644381  0.956410
# GraphST      0.752520      0.900632  0.468827           0.559720  0.906869
# SPIRAL       0.617939      0.485104  0.488668           0.555423  0.924869
#
#            ...       NMI  info_mean  info_median  spatial_coherence_score  \
# method     ...
# harmony    ...  0.660300   0.680946     0.652936                 0.696398
# STAGATE    ...  0.558426   0.644541     0.606791                 0.834084
# seurat     ...  0.626866   0.664495     0.628360                 0.672144
# STAligner  ...  0.565306   0.628932     0.604116                 0.875916
# DeepST     ...  0.562553   0.634875     0.597655                 0.846590
# PRECAST    ...  0.629318   0.638537     0.629648                 0.918695
# liger      ...  0.559311   0.614169     0.601846                 0.650047
# GraphST    ...  0.345161   0.484796     0.461465                 1.000000
# SPIRAL     ...  0.535141   0.590854     0.545282                 0.797147
#
#            Moran's I  Geary's C  spatial_mean  spatial_median      mean  \
# method
# harmony     0.651782   0.510970      0.619717        0.651782  0.581397
# STAGATE     0.979941   0.499627      0.771217        0.834084  0.590379
# seurat      0.651168   0.508474      0.610595        0.651168  0.593597
# STAligner   0.978417   0.500066      0.784800        0.875916  0.602336
# DeepST      0.814281   0.464302      0.708391        0.814281  0.613091
# PRECAST     0.967766   0.500208      0.795556        0.918695  0.622098
# liger       0.915089   0.492474      0.685870        0.650047  0.633726
# GraphST     0.816784   0.513017      0.776600        0.816784  0.671306
# SPIRAL      0.853422   0.882731      0.844433        0.853422  0.684409
#
#              median
# method
# harmony    0.527711
# STAGATE    0.533800
# seurat     0.544024
# STAligner  0.568928
# DeepST     0.691857
# PRECAST    0.631659
# liger      0.597631
# GraphST    0.726294
# SPIRAL     0.627936
#
# [9 rows x 22 columns]

# %%
df2

# %%
df_res = (df1 + df2 + df3 + df4)/4
# df_res = (df1 + df2)/2
# df_res = (df3 + df4)/2
df_res = df_res.drop('SPIRAL_pyg')
df_res
# Out:
#                 PCR      iASW     iLISI      kBET  graph_connectivity  \
# method
# DeepST     0.497033  0.804885  0.377443  0.219120            0.916670
# GraphST    0.637693  0.881278  0.797668  0.374669            0.959574
# PRECAST    0.495863  0.748802  0.607620  0.410920            0.817777
# SPIRAL     0.267720  0.812515  0.319724  0.237112            0.907522
# STAGATE    0.027063  0.807717  0.307525  0.145077            0.876927
# STAligner  0.187696  0.863700  0.459585  0.216880            0.920463
# harmony    0.528065  0.890720  0.594663  0.460556            0.927516
# liger      0.786429  0.883324  0.732841  0.555761            0.916238
# seurat     0.563574  0.873713  0.606802  0.321970            0.935644
#
#            batch_mean  batch_median      cASW  IsolatedLabelsAsw     cLISI  \
# method
# DeepST       0.563030      0.572115  0.514001           0.595169  0.976870
# GraphST      0.730176      0.808549  0.510671           0.565948  0.896276
# PRECAST      0.616196      0.618217  0.580636           0.586745  0.949605
# SPIRAL       0.508919      0.323057  0.529728           0.582544  0.957701
# STAGATE      0.432862      0.347571  0.549057           0.611760  0.979815
# STAligner    0.529665      0.495671  0.543159           0.584772  0.970940
# harmony      0.680304      0.617131  0.537878           0.583292  0.952958
# liger        0.774919      0.784712  0.536606           0.588754  0.937792
# seurat       0.660341      0.752595  0.537763           0.557209  0.948147
#
#            ...       NMI  info_mean  info_median  spatial_coherence_score  \
# method     ...
# DeepST     ...  0.495229   0.588601     0.570262                 0.677844
# GraphST    ...  0.365484   0.502472     0.490720                 0.859779
# PRECAST    ...  0.494050   0.588139     0.593719                 0.558084
# SPIRAL     ...  0.530333   0.571915     0.528521                 0.749550
# STAGATE    ...  0.479204   0.561443     0.526832                 0.899176
# STAligner  ...  0.548273   0.578621     0.559016                 0.728454
# harmony    ...  0.564916   0.607205     0.575970                 0.437337
# liger      ...  0.499441   0.585131     0.566520                 0.375474
# seurat     ...  0.509383   0.576183     0.541097                 0.407463
#
#            Moran's I  Geary's C  spatial_mean  spatial_median      mean  \
# method
# DeepST      0.766790   0.775287      0.739974        0.784939  0.630535
# GraphST     0.684727   0.663249      0.735918        0.714422  0.656189
# PRECAST     0.906188   0.827687      0.763986        0.893920  0.656107
# SPIRAL      0.827989   0.866523      0.814687        0.830620  0.631840
# STAGATE     0.935785   0.824932      0.886631        0.901559  0.626979
# STAligner   0.865169   0.775618      0.789747        0.847947  0.632678
# harmony     0.483831   0.542097      0.487755        0.493161  0.591755
# liger       0.795453   0.754894      0.641940        0.729192  0.667330
# seurat      0.506407   0.575771      0.496547        0.510915  0.577690
#
#              median
# method
# DeepST     0.642439
# GraphST    0.671230
# PRECAST    0.701952
# SPIRAL     0.560733
# STAGATE    0.591987
# STAligner  0.634211
# harmony    0.562087
# liger      0.693475
# seurat     0.601536
#
# [9 rows x 22 columns]

# %%
batch_columns = ['PCR', 'iASW', 'iLISI', 'kBET', 'graph_connectivity']
info_columns = ['cASW', 'IsolatedLabelsAsw', 'cLISI', 'IsolatedLabelsF1', 'ARI', 'NMI']
spatial_columns = ['spatial_coherence_score', "Moran's I", "Geary's C"]

df_res['batch_mean'] = df_res[batch_columns].mean(axis=1, numeric_only=True)
df_res['batch_median'] = df_res[batch_columns].median(axis=1, numeric_only=True)

df_res['info_mean'] = df_res[info_columns].mean(axis=1, numeric_only=True)
df_res['info_median'] = df_res[info_columns].median(axis=1, numeric_only=True)

df_res['spatial_mean'] = df_res[spatial_columns].mean(axis=1, numeric_only=True)
df_res['spatial_median'] = df_res[spatial_columns].median(axis=1, numeric_only=True)

df_res['mean'] = df_res[['batch_mean', 'info_mean', 'spatial_mean']].mean(axis=1, numeric_only=True)
df_res['median'] = df_res[['batch_median', 'info_median', 'spatial_median']].mean(axis=1, numeric_only=True)
df_res = df_res.sort_values(by='mean',ascending=False)

df_res
# Out:
#                 PCR      iASW     iLISI      kBET  graph_connectivity  \
# method
# liger      0.786429  0.883324  0.732841  0.555761            0.916238
# GraphST    0.637693  0.881278  0.797668  0.374669            0.959574
# PRECAST    0.495863  0.748802  0.607620  0.410920            0.817777
# STAligner  0.187696  0.863700  0.459585  0.216880            0.920463
# SPIRAL     0.267720  0.812515  0.319724  0.237112            0.907522
# DeepST     0.497033  0.804885  0.377443  0.219120            0.916670
# STAGATE    0.027063  0.807717  0.307525  0.145077            0.876927
# harmony    0.528065  0.890720  0.594663  0.460556            0.927516
# seurat     0.563574  0.873713  0.606802  0.321970            0.935644
#
#            batch_mean  batch_median      cASW  IsolatedLabelsAsw     cLISI  \
# method
# liger        0.774919      0.786429  0.536606           0.588754  0.937792
# GraphST      0.730176      0.797668  0.510671           0.565948  0.896276
# PRECAST      0.616196      0.607620  0.580636           0.586745  0.949605
# STAligner    0.529665      0.459585  0.543159           0.584772  0.970940
# SPIRAL       0.508919      0.319724  0.529728           0.582544  0.957701
# DeepST       0.563030      0.497033  0.514001           0.595169  0.976870
# STAGATE      0.432862      0.307525  0.549057           0.611760  0.979815
# harmony      0.680304      0.594663  0.537878           0.583292  0.952958
# seurat       0.660341      0.606802  0.537763           0.557209  0.948147
#
#            ...       NMI  info_mean  info_median  spatial_coherence_score  \
# method     ...
# liger      ...  0.499441   0.585131     0.561050                 0.375474
# GraphST    ...  0.365484   0.502472     0.473448                 0.859779
# PRECAST    ...  0.494050   0.588139     0.583691                 0.558084
# STAligner  ...  0.548273   0.578621     0.545716                 0.728454
# SPIRAL     ...  0.530333   0.571915     0.530031                 0.749550
# DeepST     ...  0.495229   0.588601     0.554585                 0.677844
# STAGATE    ...  0.479204   0.561443     0.514130                 0.899176
# harmony    ...  0.564916   0.607205     0.574104                 0.437337
# seurat     ...  0.509383   0.576183     0.525683                 0.407463
#
#            Moran's I  Geary's C  spatial_mean  spatial_median      mean  \
# method
# liger       0.795453   0.754894      0.641940        0.754894  0.667330
# GraphST     0.684727   0.663249      0.735918        0.684727  0.656189
# PRECAST     0.906188   0.827687      0.763986        0.827687  0.656107
# STAligner   0.865169   0.775618      0.789747        0.775618  0.632678
# SPIRAL      0.827989   0.866523      0.814687        0.827989  0.631840
# DeepST      0.766790   0.775287      0.739974        0.766790  0.630535
# STAGATE     0.935785   0.824932      0.886631        0.899176  0.626979
# harmony     0.483831   0.542097      0.487755        0.483831  0.591755
# seurat      0.506407   0.575771      0.496547        0.506407  0.577690
#
#              median
# method
# liger      0.700791
# GraphST    0.651948
# PRECAST    0.672999
# STAligner  0.593640
# SPIRAL     0.559248
# DeepST     0.606136
# STAGATE    0.573611
# harmony    0.550866
# seurat     0.546297
#
# [9 rows x 22 columns]

# %%
df_res = df_res.sort_values(by='mean',ascending=True)   ##  R plot need reverse
df_res.to_csv('G:/dataset/result_pic/index_res/experiment1_slice.csv')

# %%
import pandas as pd
import numpy as np

# %%
input_dir = 'G:/dataset/result_pic/index_res/total_plot/'
files = ['DLPFC_slice.csv', 'MouseAtlas_slice.csv', 'Saggital_horizon.csv', 'LICA_horizon.csv', 
         'Sagittal_all.csv', 'BRCA.csv', 'PDAC.csv', 'mPFC.csv', 'MOp.csv', 'Coronal.csv',
        'MouseOB35.csv','MOSTA.csv']

# %%
df = pd.read_csv(input_dir + files[0])
df
# Out:
#        method       PCR      iASW     iLISI      kBET  graph_connectivity  \
# 0      seurat  0.938748  0.942101  0.687906  0.396598            0.943396
# 1     harmony  0.969371  0.971135  0.766942  0.610741            0.917340
# 2       liger  0.952098  0.959922  0.852611  0.693390            0.902858
# 3     STAGATE  0.108252  0.898148  0.579485  0.039692            0.951751
# 4      DeepST  0.735837  0.851526  0.709939  0.267820            0.939433
# 5     GraphST  0.893290  0.953083  0.805840  0.531954            0.998172
# 6     PRECAST  0.792334  0.855393  0.843518  0.561619            0.797107
# 7      SPIRAL  0.588549  0.951173  0.749033  0.492288            0.983729
# 8  SPIRAL_pyg  0.609274  0.949214  0.748624  0.484411            0.982188
# 9   STAligner  0.370567  0.926629  0.651797  0.162223            0.999118
#
#    batch_mean  batch_median      cASW  IsolatedLabelsAsw  ...       NMI  \
# 0    0.781750      0.938748  0.505676           0.506616  ...  0.318756
# 1    0.847106      0.917340  0.509715           0.507820  ...  0.410636
# 2    0.872176      0.902858  0.511498           0.510783  ...  0.353798
# 3    0.515466      0.579485  0.535499           0.534149  ...  0.544149
# 4    0.700911      0.735837  0.523361           0.513851  ...  0.561420
# 5    0.836468      0.893290  0.512429           0.516431  ...  0.409391
# 6    0.769994      0.797107  0.537252           0.510357  ...  0.522732
# 7    0.752954      0.749033  0.544527           0.539175  ...  0.580758
# 8    0.754742      0.748624  0.541974           0.542432  ...  0.586912
# 9    0.622067      0.651797  0.536681           0.541658  ...  0.528733
#
#    info_mean  info_median  spatial_coherence_score  Moran's I  Geary's C  \
# 0   0.496900     0.501652                 0.385144   0.449662   0.602010
# 1   0.522007     0.508767                 0.362230   0.374033   0.517904
# 2   0.507740     0.511141                 0.274952   0.646972   0.806601
# 3   0.605110     0.539824                 0.880255   0.903505   0.916085
# 4   0.615356     0.542390                 0.721372   0.648778   0.827158
# 5   0.524461     0.514430                 0.945565   0.603774   0.688557
# 6   0.569184     0.524458                 0.556867   0.854147   0.906503
# 7   0.628253     0.562642                 0.694522   0.729415   0.779784
# 8   0.633307     0.564672                 0.633169   0.764939   0.805488
# 9   0.601834     0.539169                 1.000000   0.862498   0.887053
#
#    spatial_mean  spatial_median      mean    median
# 0      0.478939        0.449662  0.585863  0.630021
# 1      0.418056        0.374033  0.595723  0.600047
# 2      0.576175        0.646972  0.652030  0.686990
# 3      0.899948        0.903505  0.673508  0.674271
# 4      0.732436        0.721372  0.682901  0.666533
# 5      0.745966        0.688557  0.702298  0.698759
# 6      0.772505        0.854147  0.703894  0.725237
# 7      0.734574        0.729415  0.705260  0.680364
#  7      0.947096        0.951030  0.705959  0.757197
#  8      0.968459        0.955830  0.710704  0.759236
#  9      0.836922        0.828038  0.672129  0.741141
#
#  [10 rows x 23 columns]]

# %%
df = pd.concat(df_list)
df
# Out:
#         method       PCR      iASW     iLISI      kBET  graph_connectivity  \
# 0       seurat  0.938748  0.942101  0.687906  0.396598            0.943396
# 1      harmony  0.969371  0.971135  0.766942  0.610741            0.917340
# 2        liger  0.952098  0.959922  0.852611  0.693390            0.902858
# 3      STAGATE  0.108252  0.898148  0.579485  0.039692            0.951751
# 4       DeepST  0.735837  0.851526  0.709939  0.267820            0.939433
# ..         ...       ...       ...       ...       ...                 ...
# 5   SPIRAL_pyg  0.991405  0.883402  0.296289  0.140752            0.940191
# 6        liger  0.996681  0.836188  0.386540  0.325908            0.814341
# 7      STAGATE  0.980955  0.832256  0.269768  0.120322            0.961053
# 8    STAligner  0.982223  0.836291  0.278120  0.115495            0.961626
# 9       SPIRAL  0.991405  0.883402  0.296289  0.140752            0.940191
#
#     batch_mean  batch_median      cASW  IsolatedLabelsAsw  ...       NMI  \
# 0     0.781750      0.938748  0.505676           0.506616  ...  0.318756
# 1     0.847106      0.917340  0.509715           0.507820  ...  0.410636
# 2     0.872176      0.902858  0.511498           0.510783  ...  0.353798
# 3     0.515466      0.579485  0.535499           0.534149  ...  0.544149
# 4     0.700911      0.735837  0.523361           0.513851  ...  0.561420
# ..         ...           ...       ...                ...  ...       ...
# 5     0.650408      0.883402  0.505142           0.518820  ...  0.539910
# 6     0.671931      0.814341  0.496660           0.464194  ...  0.484175
# 7     0.632871      0.832256  0.482072           0.494535  ...  0.543888
# 8     0.634751      0.836291  0.479721           0.491454  ...  0.540516
# 9     0.650408      0.883402  0.505142           0.518820  ...  0.539910
#
#     info_mean  info_median  spatial_coherence_score  Moran's I  Geary's C  \
# 0    0.496900     0.501652                 0.385144   0.449662   0.602010
# 1    0.522007     0.508767                 0.362230   0.374033   0.517904
# 2    0.507740     0.511141                 0.274952   0.646972   0.806601
# 3    0.605110     0.539824                 0.880255   0.903505   0.916085
# 4    0.615356     0.542390                 0.721372   0.648778   0.827158
# ..        ...          ...                      ...        ...        ...
# 5    0.529059     0.511981                 0.812544   0.828038   0.870184
# 6    0.493373     0.474184                 0.707488   0.930177   0.948561
# 7    0.537910     0.488304                 0.933720   0.951030   0.956539
# 8    0.528901     0.485587                 1.000000   0.949548   0.955830
# 9    0.529059     0.511981                 0.812544   0.828038   0.870184
#
#     spatial_mean  spatial_median      mean    median
# 0       0.478939        0.449662  0.585863  0.630021
# 1       0.418056        0.374033  0.595723  0.600047
# 2       0.576175        0.646972  0.652030  0.686990
# 3       0.899948        0.903505  0.673508  0.674271
# 4       0.732436        0.721372  0.682901  0.666533
# ..           ...             ...       ...       ...
# 5       0.836922        0.828038  0.672129  0.741141
# 6       0.862075        0.930177  0.675793  0.739568
# 7       0.947096        0.951030  0.705959  0.757197
# 8       0.968459        0.955830  0.710704  0.759236
# 9       0.836922        0.828038  0.672129  0.741141
#
# [113 rows x 23 columns]

# %%
df.mean
